# %%
# AI Prototype Notebook

# Purpose:
# - Test Gemini API
# - Experiment with prompts
# - Debug responses

# NOTE:
# Production logic is in ai_service.py

from google import genai
import os
from dotenv import load_dotenv

load_dotenv()

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

# Try multiple models because availability/quota is model-specific

models = [
    "gemini-2.5-flash",
    "gemini-2.0-flash",
    "gemini-1.5-flash",
    "gemini-flash-latest"
]

response = None
last_error = None

for m in models:
    try:
        response = client.models.generate_content(
            model=m,
            contents="I just started my trip to Mumbai, any tips?"
        )
        print("Using model:", m)
        break
    except Exception as e:
        last_error = e
        print("Failed model:", m, e)

if response:
    print(response.text)
else:
    print("All models failed:", last_error)
# Out:
# Using model: gemini-2.5-flash
# Welcome to Mumbai, the City of Dreams! You're in for an incredible, vibrant, and often chaotic experience. Here are some tips to help you make the most of your trip:
#
# ## Getting Around
#
# 1.  **Local Trains: The Lifeline!**
#     *   **Pros:** Fastest way to cover long distances, incredibly cheap, a truly authentic experience.
#     *   **Cons:** EXTREMELY crowded during peak hours (8-11 AM & 5-8 PM). Not for the faint of heart then.
#     *   **Tip:** Try a ride during off-peak hours (late morning, early afternoon) for the experience. Look for the **"Ladies Compartment"** if you're a woman travelling solo – it's safer and less crowded.
#
# 2.  **Auto-Rickshaws (3-wheelers):**
#     *   **Where:** Common in the suburbs (north of Bandra-Worli Sea Link). You won't find them in South Mumbai (Colaba, Fort area).
# ...
